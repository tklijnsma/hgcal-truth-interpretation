# %%
import importlib
import ntuputils, trees
import numpy as np, os.path as osp, matplotlib.pyplot as plt

# %%
importlib.reload(ntuputils)
event = ntuputils.get_event('event1009_pdgid13_1000GeV_Nov10_finecalo_numEvent5_numEvent5.root', i=0)
# Out:
#    INFO:2020-11-24 12:28:41:ntuputils:17 Logger hgcalplot is already defined
#    INFO:2020-11-24 12:28:41:ntuputils:40 Using tqdm notebook
#    INFO:2020-11-24 12:28:41:ntuputils:161 Overwriting cache for <ntuputils.Dataset (1 root files) object at 0x1889514f0>
# HBox(children=(HTML(value='root files'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
#    INFO:2020-11-24 12:28:41:ntuputils:171 Cached ~677.6 kb (5 entries, 53 branches)
#    INFO:2020-11-24 12:28:41:ntuputils:128 Using cache

# %%
importlib.reload(trees)
roots = trees.build_tree(event)
root = roots[1]
# Out:
#    INFO:2020-11-24 12:22:03:trees:164 Adding <trees.Track 1 E=5269.00 (0.000,0.000,-0.000) pdgid=-13 at 0x17741c9d0> as a root
#    INFO:2020-11-24 12:22:03:trees:164 Adding <trees.Track 2 E=5269.00 (0.000,0.000,-0.000) pdgid=13 at 0x17703f7c0> as a root

# %%
trees.print_tree(root)
# Out:
# 2 E=5269.00 pdg=13 nhits=878 X
# __13 E=2.08 pdg=11
# ____139656 E=0.04 pdg=22 nhits=1 X
# ____139659 E=0.05 pdg=22 nhits=1 X
# ____139660 E=0.87 pdg=22
# ______141142 E=0.86 pdg=-11 nhits=2 X
# ________141145 E=0.15 pdg=22
# __________142156 E=0.11 pdg=11 nhits=2 X
# ____________142207 E=0.05 pdg=22 nhits=1 X
# __________142157 E=0.04 pdg=-11 nhits=1 X
# ________141149 E=0.04 pdg=22 nhits=2 X
# ________141150 E=0.44 pdg=22
# __________141429 E=0.26 pdg=11 nhits=7 X
# ____________141677 E=0.03 pdg=22 nhits=3 X
# ____________141678 E=0.04 pdg=22 nhits=1 X
# __________141430 E=0.18 pdg=-11 nhits=11 X
# ________141155 E=0.02 pdg=22 nhits=3 X
# ________141156 E=0.12 pdg=22 nhits=4 X
# ____139661 E=1.08 pdg=11
# ______139663 E=0.05 pdg=22 nhits=1 X
# ______139696 E=0.29 pdg=22 nhits=7 X
# ______139704 E=0.60 pdg=22
# ________139710 E=0.10 pdg=11 nhits=1 X
# ________139711 E=0.49 pdg=-11 nhits=12 X
# __________139714 E=0.03 pdg=22 nhits=2 X
# __________139715 E=0.14 pdg=22 nhits=5 X
# __________139717 E=0.10 pdg=22
# ____________140068 E=0.09 pdg=-11 nhits=5 X
# __________139718 E=0.10 pdg=22 nhits=2 X
# __________139721 E=0.01 pdg=22 nhits=1 X
# __14 E=0.43 pdg=-11
# ____139028 E=0.41 pdg=22
# ______139032 E=0.19 pdg=11 nhits=12 X
# ______139033 E=0.22 pdg=-11 nhits=18 X
# __836 E=14.69 pdg=11
# ____27580 E=9.99 pdg=11
# ______27607 E=0.92 pdg=22
# ________33244 E=0.72 pdg=11
# __________33466 E=0.07 pdg=22
# ____________33737 E=0.05 pdg=-11 nhits=1 X
# __837 E=3.61 pdg=-11
# ____23450 E=2.77 pdg=-11
# ______23458 E=1.04 pdg=22
# ________25187 E=0.39 pdg=-11
# __________25220 E=0.21 pdg=22
# ____________25309 E=0.15 pdg=-11
# ______________25332 E=0.04 pdg=22
# ________________25396 E=0.02 pdg=-11
# __________________25404 E=0.00 pdg=22 nhits=1 X

# %%
importlib.reload(trees)
trees.plot_graph(root, prog='neato')

# %%
fig = plt.figure(figsize=(24,12))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122, projection='3d')

labels=False
trees.plot_node(root, labels=labels, ax=ax1)
trees.plot_node_rotated(root, labels=labels, ax=ax2)

# %% [markdown]
# Focusing on subtree starting with track 13:

# %%
track13 = root.get_by_id(13)
trees.plot_node_rotated(track13, labels=True)
trees.plot_graph(track13)
track13.print()
# Out:
# 13 E=2.08 pdg=11
# __139656 E=0.04 pdg=22 nhits=1 X
# __139659 E=0.05 pdg=22 nhits=1 X
# __139660 E=0.87 pdg=22
# ____141142 E=0.86 pdg=-11 nhits=2 X
# ______141145 E=0.15 pdg=22
# ________142156 E=0.11 pdg=11 nhits=2 X
# __________142207 E=0.05 pdg=22 nhits=1 X
# ________142157 E=0.04 pdg=-11 nhits=1 X
# ______141149 E=0.04 pdg=22 nhits=2 X
# ______141150 E=0.44 pdg=22
# ________141429 E=0.26 pdg=11 nhits=7 X
# __________141677 E=0.03 pdg=22 nhits=3 X
# __________141678 E=0.04 pdg=22 nhits=1 X
# ________141430 E=0.18 pdg=-11 nhits=11 X
# ______141155 E=0.02 pdg=22 nhits=3 X
# ______141156 E=0.12 pdg=22 nhits=4 X
# __139661 E=1.08 pdg=11
# ____139663 E=0.05 pdg=22 nhits=1 X
# ____139696 E=0.29 pdg=22 nhits=7 X
# ____139704 E=0.60 pdg=22
# ______139710 E=0.10 pdg=11 nhits=1 X
# ______139711 E=0.49 pdg=-11 nhits=12 X
# ________139714 E=0.03 pdg=22 nhits=2 X
# ________139715 E=0.14 pdg=22 nhits=5 X
# ________139717 E=0.10 pdg=22
# __________140068 E=0.09 pdg=-11 nhits=5 X
# ________139718 E=0.10 pdg=22 nhits=2 X
# ________139721 E=0.01 pdg=22 nhits=1 X

# %% [markdown]
# Printing more events:

# %%
labels = False
for event in ntuputils.iter_events('event1009_pdgid13_1000GeV_Nov10_finecalo_numEvent5_numEvent5.root'):
    roots = trees.build_tree(event)
    fig = plt.figure(figsize=(24,12))
    ax1 = fig.add_subplot(121, projection='3d')
    ax2 = fig.add_subplot(122, projection='3d')
    trees.plot_node_rotated(roots[0], labels=labels, ax=ax1)
    trees.plot_node_rotated(roots[1], labels=labels, ax=ax2)
# Out:
#    INFO:2020-11-24 12:30:19:ntuputils:161 Overwriting cache for <ntuputils.Dataset (1 root files) object at 0x187af5970>
# HBox(children=(HTML(value='root files'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
#    INFO:2020-11-24 12:30:19:ntuputils:171 Cached ~677.6 kb (5 entries, 53 branches)
#    INFO:2020-11-24 12:30:19:ntuputils:128 Using cache
# HBox(children=(HTML(value='arrays'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
#    INFO:2020-11-24 12:30:19:trees:164 Adding <trees.Track 1 E=5269.00 (0.000,0.000,-0.000) pdgid=-13 at 0x187e73c10> as a root
#    INFO:2020-11-24 12:30:19:trees:164 Adding <trees.Track 2 E=5269.00 (0.000,0.000,-0.000) pdgid=13 at 0x187e73a90> as a root
#    INFO:2020-11-24 12:30:20:trees:164 Adding <trees.Track 1 E=5476.07 (0.000,-0.000,0.000) pdgid=-13 at 0x187e73820> as a root
#    INFO:2020-11-24 12:30:20:trees:164 Adding <trees.Track 2 E=5476.07 (0.000,-0.000,0.000) pdgid=13 at 0x187e73100> as a root
#    INFO:2020-11-24 12:30:20:trees:164 Adding <trees.Track 1 E=4498.24 (0.000,-0.000,0.000) pdgid=-13 at 0x187ff0ac0> as a root
#    INFO:2020-11-24 12:30:20:trees:164 Adding <trees.Track 2 E=4498.24 (0.000,-0.000,0.000) pdgid=13 at 0x187ff0910> as a root
#    INFO:2020-11-24 12:30:20:trees:164 Adding <trees.Track 1 E=3335.98 (0.000,-0.000,-0.000) pdgid=-13 at 0x188e28940> as a root
#    INFO:2020-11-24 12:30:20:trees:164 Adding <trees.Track 2 E=3335.98 (0.000,-0.000,-0.000) pdgid=13 at 0x188e28730> as a root
#    INFO:2020-11-24 12:30:20:trees:164 Adding <trees.Track 1 E=6097.65 (-0.000,0.000,0.000) pdgid=-13 at 0x1889619d0> as a root
#    INFO:2020-11-24 12:30:20:trees:164 Adding <trees.Track 2 E=6097.65 (-0.000,0.000,0.000) pdgid=13 at 0x188961130> as a root
